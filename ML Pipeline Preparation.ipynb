# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import re
import pickle
import pandas as pd 
from sqlalchemy import create_engine
import nltk 
from nltk.tokenize import word_tokenize 
from nltk.corpus import stopwords 
from nltk.stem import WordNetLemmatizer
from sklearn.pipeline import Pipeline 
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.multioutput import MultiOutputClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.model_selection import train_test_split,  GridSearchCV 
from sklearn.metrics import classification_report


nltk.download(['wordnet', 'punkt', 'stopwords'])
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
engine = create_engine('sqlite:///Data/DisasterResponse.db')
df = pd.read_sql_table('Disasters',engine)

X = df['message']  # Message Column
Y = df.iloc[:, 4:] # Classification label

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    """
    Function: split text into words and return the root form of the words
    Args:
      text(str): the message
    Return:
      lemm(list of str): a list of the root form of the message words
    """
    # Normalize text
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower())
    
    # Tokenize text
    words = word_tokenize(text)
    
    # Remove stop words
    stop = stopwords.words("english")
    words = [t for t in words if t not in stop]
    
    # Lemmatization
    lemm = [WordNetLemmatizer().lemmatize(w) for w in words]
    return lemm

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
moc = MultiOutputClassifier(RandomForestClassifier())

pipeline_rfc = Pipeline([
        ('vect', CountVectorizer(tokenizer = tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf',  MultiOutputClassifier(RandomForestClassifier()))
    ])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
# splitting data, train and predict
X_train, X_test, y_train, y_test = train_test_split(X, Y)

# %%
# Fit the Random Forest Classifier 
pipeline_rfc.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Pipeline(memory=None,
#          steps=[('vect',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=1,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenize at...
#                  MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True,
#                                                                         class_weight=None,
#                                                                         criterion='gini',
#                                                                         max_depth=None,
#                                                                         max_features='auto',
#                                                                         max_leaf_nodes=None,
#                                                                         min_impurity_decrease=0.0,
#                                                                         min_impurity_split=None,
#                                                                         min_samples_leaf=1,
#                                                                         min_samples_split=2,
#                                                                         min_weight_fraction_leaf=0.0,
#                                                                         n_estimators='warn',
#                                                                         n_jobs=None,
#                                                                         oob_score=False,
#                                                                         random_state=None,
#                                                                         verbose=0,
#                                                                         warm_start=False),
#                                        n_jobs=None))],
#          verbose=False)

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
def plot_scores(y_test, y_pred):
    #Testing the model
    # Printing the classification report for each label
    i = 0
    for col in y_test:
        print('Feature {}: {}'.format(i+1, col))
        print(classification_report(y_test[col], y_pred[:, i]))
        i = i + 1
    accuracy = (y_pred == y_test.values).mean()
    print('The model accuracy is {:.3f}'.format(accuracy))

# %%
# Prediction: the Random Forest Classifier  
y_pred = pipeline_rfc.predict(X_test)
plot_scores(y_test, y_pred)
# Out:
# Feature 1: 1
#               precision    recall  f1-score   support
#
#            0       0.63      0.47      0.54      1596
#            1       0.84      0.91      0.87      4944
#            2       0.60      0.26      0.37        57
#
#     accuracy                           0.80      6597
#    macro avg       0.69      0.55      0.59      6597
# weighted avg       0.79      0.80      0.79      6597
#
# Feature 2: request-0
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.94      5504
#            1       0.77      0.47      0.58      1093
#
#     accuracy                           0.89      6597
#    macro avg       0.83      0.72      0.76      6597
# weighted avg       0.88      0.89      0.88      6597
#
# Feature 3: offer-0
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6558
#            1       1.00      0.03      0.05        39
#
#     accuracy                           0.99      6597
#    macro avg       1.00      0.51      0.52      6597
# weighted avg       0.99      0.99      0.99      6597
#
# Feature 4: aid_related-0
#               precision    recall  f1-score   support
#
#            0       0.76      0.85      0.80      3942
#            1       0.73      0.61      0.67      2655
#
#     accuracy                           0.75      6597
#    macro avg       0.75      0.73      0.73      6597
# weighted avg       0.75      0.75      0.75      6597
#
# Feature 5: medical_help-0
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      6082
#            1       0.60      0.11      0.19       515
#
#     accuracy                           0.92      6597
#    macro avg       0.76      0.55      0.58      6597
# weighted avg       0.90      0.92      0.90      6597
#
# Feature 6: medical_products-0
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6292
#            1       0.64      0.08      0.15       305
#
#     accuracy                           0.96      6597
#    macro avg       0.80      0.54      0.56      6597
# weighted avg       0.94      0.96      0.94      6597
#
# Feature 7: search_and_rescue-0
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      6419
#            1       0.39      0.06      0.11       178
#
#     accuracy                           0.97      6597
#    macro avg       0.68      0.53      0.55      6597
# weighted avg       0.96      0.97      0.96      6597
#
# Feature 8: security-0
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6488
#            1       0.00      0.00      0.00       109
#
#     accuracy                           0.98      6597
#    macro avg       0.49      0.50      0.50      6597
# weighted avg       0.97      0.98      0.98      6597
#
# Feature 9: military-0
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6393
#            1       0.62      0.10      0.17       204
#
#     accuracy                           0.97      6597
#    macro avg       0.80      0.55      0.58      6597
# weighted avg       0.96      0.97      0.96      6597
#
# Feature 10: child_alone-0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6597
#
#     accuracy                           1.00      6597
#    macro avg       1.00      1.00      1.00      6597
# weighted avg       1.00      1.00      1.00      6597
#
# Feature 11: water-0
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6190
#            1       0.85      0.32      0.46       407
#
#     accuracy                           0.95      6597
#    macro avg       0.90      0.66      0.72      6597
# weighted avg       0.95      0.95      0.94      6597
#
# Feature 12: food-0
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      5866
#            1       0.82      0.52      0.64       731
#
#     accuracy                           0.93      6597
#    macro avg       0.88      0.75      0.80      6597
# weighted avg       0.93      0.93      0.93      6597
#
# Feature 13: shelter-0
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      6027
#            1       0.82      0.33      0.47       570
#
#     accuracy                           0.94      6597
#    macro avg       0.88      0.66      0.72      6597
# weighted avg       0.93      0.94      0.92      6597
#
# Feature 14: clothing-0
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6500
#            1       0.50      0.07      0.13        97
#
#     accuracy                           0.99      6597
#    macro avg       0.74      0.54      0.56      6597
# weighted avg       0.98      0.99      0.98      6597
#
# Feature 15: money-0
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6430
#            1       0.43      0.02      0.03       167
#
#     accuracy                           0.97      6597
#    macro avg       0.70      0.51      0.51      6597
# weighted avg       0.96      0.97      0.96      6597
#
# Feature 16: missing_people-0
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6530
#            1       1.00      0.03      0.06        67
#
#     accuracy                           0.99      6597
#    macro avg       1.00      0.51      0.53      6597
# weighted avg       0.99      0.99      0.99      6597
#
# Feature 17: refugees-0
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6377
#            1       0.42      0.02      0.04       220
#
#     accuracy                           0.97      6597
#    macro avg       0.69      0.51      0.51      6597
# weighted avg       0.95      0.97      0.95      6597
#
# Feature 18: death-0
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6299
#            1       0.84      0.13      0.22       298
#
#     accuracy                           0.96      6597
#    macro avg       0.90      0.56      0.60      6597
# weighted avg       0.96      0.96      0.94      6597
#
# Feature 19: other_aid-0
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.93      5747
#            1       0.41      0.04      0.07       850
#
#     accuracy                           0.87      6597
#    macro avg       0.64      0.52      0.50      6597
# weighted avg       0.81      0.87      0.82      6597
#
# Feature 20: infrastructure_related-0
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      6196
#            1       0.20      0.00      0.01       401
#
#     accuracy                           0.94      6597
#    macro avg       0.57      0.50      0.49      6597
# weighted avg       0.89      0.94      0.91      6597
#
# Feature 21: transport-0
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6298
#            1       0.65      0.15      0.24       299
#
#     accuracy                           0.96      6597
#    macro avg       0.80      0.57      0.61      6597
# weighted avg       0.95      0.96      0.94      6597
#
# Feature 22: buildings-0
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      6246
#            1       0.85      0.16      0.27       351
#
#     accuracy                           0.95      6597
#    macro avg       0.90      0.58      0.62      6597
# weighted avg       0.95      0.95      0.94      6597
#
# Feature 23: electricity-0
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6467
#            1       0.88      0.05      0.10       130
#
#     accuracy                           0.98      6597
#    macro avg       0.93      0.53      0.55      6597
# weighted avg       0.98      0.98      0.97      6597
#
# Feature 24: tools-0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6567
#            1       0.00      0.00      0.00        30
#
#     accuracy                           1.00      6597
#    macro avg       0.50      0.50      0.50      6597
# weighted avg       0.99      1.00      0.99      6597
#
# Feature 25: hospitals-0
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6525
#            1       0.00      0.00      0.00        72
#
#     accuracy                           0.99      6597
#    macro avg       0.49      0.50      0.50      6597
# weighted avg       0.98      0.99      0.98      6597
#
# Feature 26: shops-0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6565
#            1       0.00      0.00      0.00        32
#
#     accuracy                           1.00      6597
#    macro avg       0.50      0.50      0.50      6597
# weighted avg       0.99      1.00      0.99      6597
#
# Feature 27: aid_centers-0
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6521
#            1       0.00      0.00      0.00        76
#
#     accuracy                           0.99      6597
#    macro avg       0.49      0.50      0.50      6597
# weighted avg       0.98      0.99      0.98      6597
#
# Feature 28: other_infrastructure-0
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6331
#            1       0.25      0.01      0.01       266
#
#     accuracy                           0.96      6597
#    macro avg       0.60      0.50      0.50      6597
# weighted avg       0.93      0.96      0.94      6597
#
# Feature 29: weather_related-0
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      4815
#            1       0.80      0.64      0.71      1782
#
#     accuracy                           0.86      6597
#    macro avg       0.84      0.79      0.81      6597
# weighted avg       0.86      0.86      0.86      6597
#
# Feature 30: floods-0
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6030
#            1       0.90      0.38      0.54       567
#
#     accuracy                           0.94      6597
#    macro avg       0.92      0.69      0.75      6597
# weighted avg       0.94      0.94      0.93      6597
#
# Feature 31: storm-0
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96      5984
#            1       0.75      0.45      0.56       613
#
#     accuracy                           0.93      6597
#    macro avg       0.85      0.72      0.76      6597
# weighted avg       0.93      0.93      0.93      6597
#
# Feature 32: fire-0
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6535
#            1       1.00      0.03      0.06        62
#
#     accuracy                           0.99      6597
#    macro avg       1.00      0.52      0.53      6597
# weighted avg       0.99      0.99      0.99      6597
#
# Feature 33: earthquake-0
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      6033
#            1       0.85      0.72      0.78       564
#
#     accuracy                           0.97      6597
#    macro avg       0.91      0.86      0.88      6597
# weighted avg       0.96      0.97      0.96      6597
#
# Feature 34: cold-0
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6461
#            1       0.78      0.13      0.23       136
#
#     accuracy                           0.98      6597
#    macro avg       0.88      0.57      0.61      6597
# weighted avg       0.98      0.98      0.97      6597
#
# Feature 35: other_weather-0
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6252
#            1       0.57      0.07      0.12       345
#
#     accuracy                           0.95      6597
#    macro avg       0.76      0.53      0.55      6597
# weighted avg       0.93      0.95      0.93      6597
#
# Feature 36: direct_report-0
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91      5329
#            1       0.71      0.34      0.46      1268
#
#     accuracy                           0.85      6597
#    macro avg       0.79      0.66      0.69      6597
# weighted avg       0.83      0.85      0.83      6597
#
# The model accuracy is 0.946
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
pipeline_rfc.get_params()
# Out:
# {'memory': None,
#  'steps': [('vect',
#    CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                    dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                    lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                    ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                    strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                    tokenizer=<function tokenize at 0x0000021867BB8598>,
#                    vocabulary=None)),
#   ('tfidf',
#    TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)),
#   ('clf',
#    MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True,
#                                                           class_weight=None,
#                                                           criterion='gini',
#                                                           max_depth=None,
#                                                           max_features='auto',
#                                                           max_leaf_nodes=None,
#                                                           min_impurity_decrease=0.0,
#                                                           min_impurity_split=None,
#                                                           min_samples_leaf=1,
#                                                           min_samples_split=2,
#                                                           min_weight_fraction_leaf=0.0,
#                                                           n_estimators='warn',
#                                                           n_jobs=None,
#                                                           oob_score=False,
#                                                           random_state=None,
#                                                           verbose=0,
#                                                           warm_start=False),
#                          n_jobs=None))],
#  'verbose': False,
#  'vect': CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                  dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                  lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                  ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                  strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                  tokenizer=<function tokenize at 0x0000021867BB8598>,
#                  vocabulary=None),
#  'tfidf': TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True),
#  'clf': MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True,
#                                                         class_weight=None,
#                                                         criterion='gini',
#                                                         max_depth=None,
#                                                         max_features='auto',
#                                                         max_leaf_nodes=None,
#                                                         min_impurity_decrease=0.0,
#                                                         min_impurity_split=None,
#                                                         min_samples_leaf=1,
#                                                         min_samples_split=2,
#                                                         min_weight_fraction_leaf=0.0,
#                                                         n_estimators='warn',
#                                                         n_jobs=None,
#                                                         oob_score=False,
#                                                         random_state=None,
#                                                         verbose=0,
#                                                         warm_start=False),
#                        n_jobs=None),
#  'vect__analyzer': 'word',
#  'vect__binary': False,
#  'vect__decode_error': 'strict',
#  'vect__dtype': numpy.int64,
#  'vect__encoding': 'utf-8',
#  'vect__input': 'content',
#  'vect__lowercase': True,
#  'vect__max_df': 1.0,
#  'vect__max_features': None,
#  'vect__min_df': 1,
#  'vect__ngram_range': (1, 1),
#  'vect__preprocessor': None,
#  'vect__stop_words': None,
#  'vect__strip_accents': None,
#  'vect__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'vect__tokenizer': <function __main__.tokenize(text)>,
#  'vect__vocabulary': None,
#  'tfidf__norm': 'l2',
#  'tfidf__smooth_idf': True,
#  'tfidf__sublinear_tf': False,
#  'tfidf__use_idf': True,
#  'clf__estimator__bootstrap': True,
#  'clf__estimator__class_weight': None,
#  'clf__estimator__criterion': 'gini',
#  'clf__estimator__max_depth': None,
#  'clf__estimator__max_features': 'auto',
#  'clf__estimator__max_leaf_nodes': None,
#  'clf__estimator__min_impurity_decrease': 0.0,
#  'clf__estimator__min_impurity_split': None,
#  'clf__estimator__min_samples_leaf': 1,
#  'clf__estimator__min_samples_split': 2,
#  'clf__estimator__min_weight_fraction_leaf': 0.0,
#  'clf__estimator__n_estimators': 'warn',
#  'clf__estimator__n_jobs': None,
#  'clf__estimator__oob_score': False,
#  'clf__estimator__random_state': None,
#  'clf__estimator__verbose': 0,
#  'clf__estimator__warm_start': False,
#  'clf__estimator': RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                         max_depth=None, max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, n_estimators='warn',
#                         n_jobs=None, oob_score=False, random_state=None,
#                         verbose=0, warm_start=False),
#  'clf__n_jobs': None}

# %%
# Using grid search
# Create Grid search parameters for Random Forest Classifier   
parameters_rfc = {
        'tfidf__use_idf': (True, False),
        'clf__estimator__n_estimators': [10, 20]
}

cv_rfc = GridSearchCV(pipeline_rfc, param_grid = parameters_rfc)
cv_rfc
# Out:
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('vect',
#                                         CountVectorizer(analyzer='word',
#                                                         binary=False,
#                                                         decode_error='strict',
#                                                         dtype=<class 'numpy.int64'>,
#                                                         encoding='utf-8',
#                                                         input='content',
#                                                         lowercase=True,
#                                                         max_df=1.0,
#                                                         max_features=None,
#                                                         min_df=1,
#                                                         ngram_range=(1, 1),
#                                                         preprocessor=None,
#                                                         stop_words=None,
#                                                         strip_accents=Non...
#                                                                                                min_samples_split=2,
#                                                                                                min_weight_fraction_leaf=0.0,
#                                                                                                n_estimators='warn',
#                                                                                                n_jobs=None,
#                                                                                                oob_score=False,
#                                                                                                random_state=None,
#                                                                                                verbose=0,
#                                                                                                warm_start=False),
#                                                               n_jobs=None))],
#                                 verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'clf__estimator__n_estimators': [10, 20],
#                          'tfidf__use_idf': (True, False)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
# Fit the first tuned model
cv_rfc.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('vect',
#                                         CountVectorizer(analyzer='word',
#                                                         binary=False,
#                                                         decode_error='strict',
#                                                         dtype=<class 'numpy.int64'>,
#                                                         encoding='utf-8',
#                                                         input='content',
#                                                         lowercase=True,
#                                                         max_df=1.0,
#                                                         max_features=None,
#                                                         min_df=1,
#                                                         ngram_range=(1, 1),
#                                                         preprocessor=None,
#                                                         stop_words=None,
#                                                         strip_accents=Non...
#                                                                                                min_samples_split=2,
#                                                                                                min_weight_fraction_leaf=0.0,
#                                                                                                n_estimators='warn',
#                                                                                                n_jobs=None,
#                                                                                                oob_score=False,
#                                                                                                random_state=None,
#                                                                                                verbose=0,
#                                                                                                warm_start=False),
#                                                               n_jobs=None))],
#                                 verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'clf__estimator__n_estimators': [10, 20],
#                          'tfidf__use_idf': (True, False)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
# Predicting using the first tuned model 
y_pred = cv_rfc.predict(X_test)
plot_scores(y_test, y_pred)
# Out:
# Feature 1: 1
#               precision    recall  f1-score   support
#
#            0       0.69      0.44      0.54      1596
#            1       0.84      0.93      0.88      4944
#            2       0.48      0.40      0.44        57
#
#     accuracy                           0.81      6597
#    macro avg       0.67      0.59      0.62      6597
# weighted avg       0.80      0.81      0.79      6597
#
# Feature 2: request-0
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      5504
#            1       0.81      0.49      0.61      1093
#
#     accuracy                           0.90      6597
#    macro avg       0.86      0.73      0.78      6597
# weighted avg       0.89      0.90      0.89      6597
#
# Feature 3: offer-0
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6558
#            1       1.00      0.03      0.05        39
#
#     accuracy                           0.99      6597
#    macro avg       1.00      0.51      0.52      6597
# weighted avg       0.99      0.99      0.99      6597
#
# Feature 4: aid_related-0
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82      3942
#            1       0.74      0.69      0.72      2655
#
#     accuracy                           0.78      6597
#    macro avg       0.77      0.76      0.77      6597
# weighted avg       0.78      0.78      0.78      6597
#
# Feature 5: medical_help-0
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      6082
#            1       0.56      0.06      0.11       515
#
#     accuracy                           0.92      6597
#    macro avg       0.74      0.53      0.54      6597
# weighted avg       0.90      0.92      0.89      6597
#
# Feature 6: medical_products-0
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6292
#            1       0.67      0.10      0.18       305
#
#     accuracy                           0.96      6597
#    macro avg       0.81      0.55      0.58      6597
# weighted avg       0.94      0.96      0.94      6597
#
# Feature 7: search_and_rescue-0
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6419
#            1       0.53      0.10      0.16       178
#
#     accuracy                           0.97      6597
#    macro avg       0.75      0.55      0.57      6597
# weighted avg       0.96      0.97      0.96      6597
#
# Feature 8: security-0
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6488
#            1       0.00      0.00      0.00       109
#
#     accuracy                           0.98      6597
#    macro avg       0.49      0.50      0.50      6597
# weighted avg       0.97      0.98      0.98      6597
#
# Feature 9: military-0
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      6393
#            1       0.80      0.08      0.14       204
#
#     accuracy                           0.97      6597
#    macro avg       0.89      0.54      0.56      6597
# weighted avg       0.97      0.97      0.96      6597
#
# Feature 10: child_alone-0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6597
#
#     accuracy                           1.00      6597
#    macro avg       1.00      1.00      1.00      6597
# weighted avg       1.00      1.00      1.00      6597
#
# Feature 11: water-0
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6190
#            1       0.85      0.35      0.49       407
#
#     accuracy                           0.96      6597
#    macro avg       0.90      0.67      0.74      6597
# weighted avg       0.95      0.96      0.95      6597
#
# Feature 12: food-0
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      5866
#            1       0.81      0.62      0.70       731
#
#     accuracy                           0.94      6597
#    macro avg       0.88      0.80      0.83      6597
# weighted avg       0.94      0.94      0.94      6597
#
# Feature 13: shelter-0
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      6027
#            1       0.82      0.34      0.48       570
#
#     accuracy                           0.94      6597
#    macro avg       0.88      0.67      0.72      6597
# weighted avg       0.93      0.94      0.92      6597
#
# Feature 14: clothing-0
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6500
#            1       0.90      0.09      0.17        97
#
#     accuracy                           0.99      6597
#    macro avg       0.94      0.55      0.58      6597
# weighted avg       0.99      0.99      0.98      6597
#
# Feature 15: money-0
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6430
#            1       0.71      0.03      0.06       167
#
#     accuracy                           0.98      6597
#    macro avg       0.84      0.51      0.52      6597
# weighted avg       0.97      0.98      0.96      6597
#
# Feature 16: missing_people-0
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6530
#            1       0.00      0.00      0.00        67
#
#     accuracy                           0.99      6597
#    macro avg       0.49      0.50      0.50      6597
# weighted avg       0.98      0.99      0.98      6597
#
# Feature 17: refugees-0
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6377
#            1       0.44      0.07      0.12       220
#
#     accuracy                           0.97      6597
#    macro avg       0.70      0.53      0.55      6597
# weighted avg       0.95      0.97      0.95      6597
#
# Feature 18: death-0
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6299
#            1       0.81      0.22      0.35       298
#
#     accuracy                           0.96      6597
#    macro avg       0.89      0.61      0.67      6597
# weighted avg       0.96      0.96      0.95      6597
#
# Feature 19: other_aid-0
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93      5747
#            1       0.56      0.05      0.10       850
#
#     accuracy                           0.87      6597
#    macro avg       0.72      0.52      0.51      6597
# weighted avg       0.84      0.87      0.82      6597
#
# Feature 20: infrastructure_related-0
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      6196
#            1       0.50      0.01      0.01       401
#
#     accuracy                           0.94      6597
#    macro avg       0.72      0.50      0.49      6597
# weighted avg       0.91      0.94      0.91      6597
#
# Feature 21: transport-0
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6298
#            1       0.72      0.12      0.21       299
#
#     accuracy                           0.96      6597
#    macro avg       0.84      0.56      0.59      6597
# weighted avg       0.95      0.96      0.94      6597
#
# Feature 22: buildings-0
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6246
#            1       0.77      0.12      0.20       351
#
#     accuracy                           0.95      6597
#    macro avg       0.86      0.56      0.59      6597
# weighted avg       0.94      0.95      0.93      6597
#
# Feature 23: electricity-0
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6467
#            1       1.00      0.06      0.12       130
#
#     accuracy                           0.98      6597
#    macro avg       0.99      0.53      0.55      6597
# weighted avg       0.98      0.98      0.97      6597
#
# Feature 24: tools-0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6567
#            1       0.00      0.00      0.00        30
#
#     accuracy                           1.00      6597
#    macro avg       0.50      0.50      0.50      6597
# weighted avg       0.99      1.00      0.99      6597
#
# Feature 25: hospitals-0
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6525
#            1       0.00      0.00      0.00        72
#
#     accuracy                           0.99      6597
#    macro avg       0.49      0.50      0.50      6597
# weighted avg       0.98      0.99      0.98      6597
#
# Feature 26: shops-0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6565
#            1       0.00      0.00      0.00        32
#
#     accuracy                           1.00      6597
#    macro avg       0.50      0.50      0.50      6597
# weighted avg       0.99      1.00      0.99      6597
#
# Feature 27: aid_centers-0
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6521
#            1       0.00      0.00      0.00        76
#
#     accuracy                           0.99      6597
#    macro avg       0.49      0.50      0.50      6597
# weighted avg       0.98      0.99      0.98      6597
#
# Feature 28: other_infrastructure-0
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6331
#            1       0.20      0.00      0.01       266
#
#     accuracy                           0.96      6597
#    macro avg       0.58      0.50      0.49      6597
# weighted avg       0.93      0.96      0.94      6597
#
# Feature 29: weather_related-0
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91      4815
#            1       0.82      0.65      0.73      1782
#
#     accuracy                           0.87      6597
#    macro avg       0.85      0.80      0.82      6597
# weighted avg       0.86      0.87      0.86      6597
#
# Feature 30: floods-0
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6030
#            1       0.89      0.41      0.56       567
#
#     accuracy                           0.94      6597
#    macro avg       0.92      0.70      0.77      6597
# weighted avg       0.94      0.94      0.94      6597
#
# Feature 31: storm-0
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      5984
#            1       0.77      0.49      0.60       613
#
#     accuracy                           0.94      6597
#    macro avg       0.86      0.74      0.78      6597
# weighted avg       0.93      0.94      0.93      6597
#
# Feature 32: fire-0
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6535
#            1       0.00      0.00      0.00        62
#
#     accuracy                           0.99      6597
#    macro avg       0.50      0.50      0.50      6597
# weighted avg       0.98      0.99      0.99      6597
#
# Feature 33: earthquake-0
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      6033
#            1       0.85      0.78      0.81       564
#
#     accuracy                           0.97      6597
#    macro avg       0.92      0.88      0.90      6597
# weighted avg       0.97      0.97      0.97      6597
#
# Feature 34: cold-0
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6461
#            1       0.81      0.10      0.17       136
#
#     accuracy                           0.98      6597
#    macro avg       0.90      0.55      0.58      6597
# weighted avg       0.98      0.98      0.97      6597
#
# Feature 35: other_weather-0
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6252
#            1       0.47      0.02      0.04       345
#
#     accuracy                           0.95      6597
#    macro avg       0.71      0.51      0.51      6597
# weighted avg       0.92      0.95      0.92      6597
#
# Feature 36: direct_report-0
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91      5329
#            1       0.76      0.35      0.48      1268
#
#     accuracy                           0.85      6597
#    macro avg       0.81      0.66      0.70      6597
# weighted avg       0.84      0.85      0.83      6597
#
# The model accuracy is 0.948
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
cv_rfc.best_estimator_
# Out:
# Pipeline(memory=None,
#          steps=[('vect',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=1,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenize at...
#                  MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True,
#                                                                         class_weight=None,
#                                                                         criterion='gini',
#                                                                         max_depth=None,
#                                                                         max_features='auto',
#                                                                         max_leaf_nodes=None,
#                                                                         min_impurity_decrease=0.0,
#                                                                         min_impurity_split=None,
#                                                                         min_samples_leaf=1,
#                                                                         min_samples_split=2,
#                                                                         min_weight_fraction_leaf=0.0,
#                                                                         n_estimators=20,
#                                                                         n_jobs=None,
#                                                                         oob_score=False,
#                                                                         random_state=None,
#                                                                         verbose=0,
#                                                                         warm_start=False),
#                                        n_jobs=None))],
#          verbose=False)

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
pickle.dump(cv_rfc, open('classifier.pkl', 'wb'))

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
